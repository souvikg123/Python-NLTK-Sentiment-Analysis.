# %%
import numpy as np # linear algebra
import pandas as pd #To read csv data (Tweets stored in CSV file)
from sklearn.model_selection import train_test_split # function for splitting data to train and test sets

import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

from subprocess import check_output

# %%
#Read Tweets from CSV file
data = pd.read_csv('Sentiment.csv')

# Keeping only the neccessary columns
data = data[['text','sentiment']]

# %%
#Deselect  the neutral tweets
data = data[data.sentiment != 'Neutral']

#Split the dataset into train and test set
train , test = train_test_split(data ,test_size = 0.2)

# %%
train.head(10)
# Out:
#                                                     text sentiment
# 635    RT @whoisbenchang: The #GOPDebate as theater, ...  Negative
# 5389   Notice last night nothing about climate change...  Negative
# 7829   . @RandPaul … poor Paul. I'm afraid @realDonal...  Negative
# 12098  Hey Rand, say negotiate one more time #GOPDebates  Negative
# 457    RT @WAGNERGIRLE: Thank you @tedcruz for speaki...  Positive
# 2001   @megynkelly going.Ronda Rousey on @realDonaldT...  Negative
# 10679  RT @jsc1835: #GOPDebates  I'd like to see this...  Negative
# 8103   RT @Lrihendry: #TedCruz As President, I will a...  Positive
# 5318   I really liked many of the candidates as peopl...  Negative
# 10091  RT @SupermanHotMale: Dear Fox News, here is my...  Negative

# %%
test.head(10)
# Out:
#                                                     text sentiment
# 12396  RT @RWSurferGirl: The candidates don't have to...  Negative
# 499    RT @amaraconda: I SWEAR TO GOD IF ANOTHER CIS ...  Negative
# 13413  #GOPDebates Smartest answers in the room tonig...  Positive
# 11356  Fox is over this. Turning this into breaking n...  Negative
# 10383  Did They Really Just Ask The Black Candidate T...  Negative
# 6357   It's scary to think just how close he could ge...  Negative
# 11631  RT @RWSurferGirl: The candidates don't have to...  Negative
# 2628   RT @UrProbsJewish: The reason there's never be...  Negative
# 13506  RT @vanesa_44: Carson is boss right now. BYE H...  Positive
# 4265   @4apostles Term limits, pay limits, &amp; perk...  Negative

# %%
train_pos = train[ train['sentiment'] == 'Positive']
train_pos = train_pos['text']
train_neg = train[ train['sentiment'] == 'Negative']
train_neg = train_neg['text']

# %%
def wordcloud_draw(data, color = 'black'):
    words = ' '.join(data)
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT'
                            ])
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=2500,
                      height=2000
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    
print("Positive words")
wordcloud_draw(train_pos,'Pink')
print("Negative words")
wordcloud_draw(train_neg)
# Out:
# Positive words
# Negative words
