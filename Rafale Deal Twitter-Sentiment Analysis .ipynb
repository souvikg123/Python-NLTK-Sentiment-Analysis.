# %%
import tweepy as tw
from textblob import TextBlob

consumer_key = 'Q2cavfdoYY6AbsENpgGudO9ds'
consumer_secret = 'ZZeQ1ToBl9DhjXPuRWwAJeN1mv3JU3eNJYhITQfvKgEawKebAi'

access_token = '3031863324-GuCJx2mNRPFdFPrD4xyEJpUIP0ZfpzuVV8X4rEn'
access_token_secret = '6v93b1RgyeYZadQ2jIudF8g2hJcxCHQZWQBWe8IzVYSxA'

aut = tw.OAuthHandler(consumer_key , consumer_secret)
aut.set_access_token(access_token,access_token_secret)

api = tw.API(aut)

public_tweets = api.search('#rafale')


i =1;
for tweet in public_tweets:
    print("Contributor :" , tweet.contributors)
    print("Co-ordinates :",tweet.coordinates)
    print("Time : ",tweet.created_at)
    print("Tweet text : " )
    print(tweet.text)
    analysis  =  TextBlob(tweet.text)
    print(analysis.sentiment)
    print("Tweet Number :" , i )
    i= i+1;
    print("___________________________")
# Out:
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 13:02:09
# Tweet text :
# RT @adrenaline1001: 🛑L'achat par l'#Inde des #Rafale français aurait profité à un homme d'affaires #indien qui aurait financé un film produ…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tweet Number : 1
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 13:01:20
# Tweet text :
# RT @ippatel: 3 #Rafale  jets landed at Gwalior airbase to train Indian pilots,while controversy is going on. These jets were returning from…
# Sentiment(polarity=0.5, subjectivity=1.0)
# Tweet Number : 2
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 13:00:26
# Tweet text :
# RT @ippatel: 3 #Rafale  jets landed at Gwalior airbase to train Indian pilots,while controversy is going on. These jets were returning from…
# Sentiment(polarity=0.5, subjectivity=1.0)
# Tweet Number : 3
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 13:00:22
# Tweet text :
# RT @DrGPradhan: अम्बानी पहले बहुत गरीब थे .लंगर मे खाना खाते थे . फिर 2014 मे मोदी आया और उन्हें अरब पति बना दिया : @RahulGandhi logic
#
# Miy…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tweet Number : 4
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 12:59:51
# Tweet text :
# RT @ippatel: 3 #Rafale  jets landed at Gwalior airbase to train Indian pilots,while controversy is going on. These jets were returning from…
# Sentiment(polarity=0.5, subjectivity=1.0)
# Tweet Number : 5
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 12:59:46
# Tweet text :
# RT @ippatel: 3 #Rafale  jets landed at Gwalior airbase to train Indian pilots,while controversy is going on. These jets were returning from…
# Sentiment(polarity=0.5, subjectivity=1.0)
# Tweet Number : 6
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 12:59:38
# Tweet text :
# RT @DrGPradhan: I disagree @Ra_THORe, Pappu is not suffering from anything. Weeds keep him high. He is actually under huge pressure from "A…
# Sentiment(polarity=0.18666666666666668, subjectivity=0.5133333333333333)
# Tweet Number : 7
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 12:59:37
# Tweet text :
# RT @ippatel: 3 #Rafale  jets landed at Gwalior airbase to train Indian pilots,while controversy is going on. These jets were returning from…
# Sentiment(polarity=0.5, subjectivity=1.0)
# Tweet Number : 8
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 12:59:32
# Tweet text :
# RT @KPCCPresident: The #Congress will hold protests against the #Rafale scam in all districts of Karnataka from September 6. The youth of t…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tweet Number : 9
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 12:58:57
# Tweet text :
# RT @vikascongress: . #FIR राबर्ट वाड्रा पर नही हुई !
# क्योंकि केस तो कोर्ट में है ही ?
# 😢😊☺
# वास्तव में FIR तो..
# @RahulGandhi को कमजोर करने
# उ…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tweet Number : 10
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 12:58:39
# Tweet text :
# RT @KPCCPresident: The #Congress will hold protests against the #Rafale scam in all districts of Karnataka from September 6. The youth of t…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tweet Number : 11
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 12:57:03
# Tweet text :
# RT @Vasudev00411816: @RahulGandhi The real Bank ROBBERY has been found in NPAs.When UPA exited in 2014, it informed the NPA to be Rs2 lakh…
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004)
# Tweet Number : 12
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 12:56:51
# Tweet text :
# RT @DrGPradhan: अम्बानी पहले बहुत गरीब थे .लंगर मे खाना खाते थे . फिर 2014 मे मोदी आया और उन्हें अरब पति बना दिया : @RahulGandhi logic
#
# Miy…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tweet Number : 13
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 12:56:02
# Tweet text :
# RT @ippatel: 3 #Rafale  jets landed at Gwalior airbase to train Indian pilots,while controversy is going on. These jets were returning from…
# Sentiment(polarity=0.5, subjectivity=1.0)
# Tweet Number : 14
# ___________________________
# Contributor : None
# Co-ordinates : None
# Time :  2018-09-03 12:55:58
# Tweet text :
# RT @ippatel: 3 #Rafale  jets landed at Gwalior airbase to train Indian pilots,while controversy is going on. These jets were returning from…
# Sentiment(polarity=0.5, subjectivity=1.0)
# Tweet Number : 15
# ___________________________
